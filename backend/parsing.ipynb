# %%
import pickle as pkl

def parse_all_patient_data():
    with open(f'/Users/brian/Documents/Impella/impella_better_ui/backend/10min_1hr_all_data.pkl', 'rb') as f:
        data = pkl.load(f)
    return data

data = parse_all_patient_data()
print(data.shape)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       5         data = pkl.load(f)
#       6     return data
# ----> 8 data = parse_all_patient_data()
#       9 print(data.shape)
#      10 print(data.head())
#
# Cell In[4], line 5, in parse_all_patient_data()
#       3 def parse_all_patient_data():
#       4     with open(f'/Users/brian/Documents/Impella/impella_better_ui/backend/10min_1hr_all_data.pkl', 'rb') as f:
# ----> 5         data = pkl.load(f)
#       6     return data
#
# ModuleNotFoundError: No module named 'torch'
